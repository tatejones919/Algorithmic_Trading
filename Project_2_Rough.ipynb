# %%
import yfinance as yf

# %%
import requests
import pandas as pd

apikey = "8YH9QLMWXNG5DNG0"

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"to_symbol":"USD","from_symbol":"EUR","function":"FX_INTRADAY","interval":"5min","datatype":"json","outputsize":"compact","apikey":"8YH9QLMWXNG5DNG0"}

headers = {
    'x-rapidapi-key': "ddb0ac8db9mshf3c30a567c94efcp14c28ejsn5c2c815427c8",
    'x-rapidapi-host': "alpha-vantage.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}

# %%
#Gold Spot Price
#gold api key = goldapi-s52s5ukptxgn8i-io
import http.client
import mimetypes
conn = http.client.HTTPSConnection("www.goldapi.io")
payload = ''
headers = {
  'x-access-token': 'goldapi-s52s5ukptxgn8i-io',
  'Content-Type': 'application/json'
}
conn.request("GET", "/api/XAU/USD", payload, headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# {"timestamp":1623512639,"metal":"XAU","currency":"USD","exchange":"FOREXCOM","symbol":"FOREXCOM:XAUUSD","prev_close_price":1898.26,"open_price":1898.26,"low_price":1874.49,"high_price":1903.03,"open_time":1623369600,"price":1877.61,"ch":-20.65,"chp":-1.09,"ask":1881.21,"bid":1879.21}

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='8YH9QLMWXNG5DNG0',output_format='pandas')
data, meta_data = ts.get_intraday(symbol='AAPL',interval='1min', outputsize='full')

# %%
from alpha_vantage.timeseries import TimeSeries
app = TimeSeries('8YH9QLMWXNG5DNG0')
gold = app.get_daily_adjusted('EURUSD')
gold
# Out:
# ({'2021-06-15': {'1. open': '1.21232',
#    '2. high': '1.21473',
#    '3. low': '1.2099',
#    '4. close': '1.2126',
#    '5. adjusted close': '1.2126',
#    '6. volume': '0',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2021-06-14': {'1. open': '1.21091',
#    '2. high': '1.21305',
#    '3. low': '1.2092',
#    '4. close': '1.21182',
#    '5. adjusted close': '1.21182',
#    '6. volume': '0',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2021-06-11': {'1. open': '1.21728',
#    '2. high': '1.2193',
#    '3. low': '1.2091',
#    '4. close': '1.2108',
#    '5. adjusted close': '1.2108',
#    '6. volume': '0',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2021-06-10': {'1. open': '1.21784',
#    '2. high': '1.21947',
#    '3. low': '1.2142',
#    '4. close': '1.2173',
#    '5. adjusted close': '1.2173',
#    '6. volume': '0',
#    '7. dividend amount': '0.0000',
# ...

# %%
date= aapl[0].keys()
close = []
for item in date:
    close.append(aapl[0][item]['4. close'])
# Out:
# ['126.11',
#  '127.13',
#  '126.74',
#  '125.9',
#  '125.89',
#  '123.54',
#  '125.06',
#  '124.28',
#  '124.61',
#  '125.28',
#  '126.85',
#  '126.9',
#  '127.1',
#  '125.43',
#  '127.31',
#  '124.69',
#  '124.85',
#  '126.27',
#  '127.45',
#  '124.97',
#  '122.77',
#  '125.91',
#  '126.85',
#  '130.21',
#  '129.74',
#  '128.1',
#  '127.85',
#  '132.54',
#  '131.46',
#  '133.48',
#  '133.58',
#  '134.39',
#  '134.72',
#  '134.32',
#  '131.94',
#  '133.5',
#  '133.11',
#  '134.84',
#  '134.16',
#  '134.5',
#  '132.03',
#  '134.43',
#  '131.24',
#  '132.995',
#  '130.36',
#  '127.9',
#  '126.21',
#  '125.9',
#  '123.0',
#  '122.15',
#  '119.9',
#  '121.39',
#  '121.21',
#  '120.59',
#  '120.09',
#  '122.54',
#  '123.39',
#  '119.99',
#  '120.53',
#  '124.76',
#  '125.57',
#  '123.99',
#  '121.03',
#  '121.96',
#  '119.98',
#  '121.085',
#  '116.36',
#  '121.42',
#  '120.13',
#  '122.06',
#  '125.12',
#  '127.79',
#  '121.26',
#  '120.99',
#  '125.35',
#  '125.86',
#  '126.0',
# ...

# %%
appl_df = pd.DataFrame(close, columns = ['Close'])
appl_df['Date']= date
appl_df
# Out:
#        Close        Date
# 0     126.11  2021-06-10
# 1     127.13  2021-06-09
# 2     126.74  2021-06-08
# 3      125.9  2021-06-07
# 4     125.89  2021-06-04
# ...      ...         ...
# 5432   88.31  1999-11-05
# 5433   83.62  1999-11-04
# 5434    81.5  1999-11-03
# 5435   80.25  1999-11-02
# 5436   77.62  1999-11-01
#
# [5437 rows x 2 columns]

# %%
json = response.json()
df = pd.DataFrame.from_dict(json)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-4d581e921884> in <module>
#       1 json = response.json()
# ----> 2 df = pd.DataFrame.from_dict(json)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1371             raise ValueError("only recognize index or columns for orient")
#    1372
# -> 1373         return cls(data, index=index, columns=columns, dtype=dtype)
#    1374
#    1375     def to_numpy(
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ...

# %%
app = ForeignExchange(output_format='pandas')

eurusd = app.get_currency_exchange_intraday('EUR', 'USD')
print(eurusd[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-64db0b34dfe5> in <module>
# ----> 1 app = ForeignExchange(output_format='pandas')
#       2
#       3 eurusd = app.get_currency_exchange_intraday('EUR', 'USD')
#       4 print(eurusd[0])
#
# NameError: name 'ForeignExchange' is not defined

# %%
import requests
import os
from alpha_vantage.foreignexchange import ForeignExchange

app = ForeignExchange(output_format='pandas')

eurusd = app.get_currency_exchange_intraday('EUR', 'USD')
print(eurusd[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-0a9ff057ee0e> in <module>
#       3 from alpha_vantage.foreignexchange import ForeignExchange
#       4
# ----> 5 app = ForeignExchange(output_format='pandas')
#       6
#       7 eurusd = app.get_currency_exchange_intraday('EUR', 'USD')
#
# /opt/anaconda3/lib/python3.8/site-packages/alpha_vantage/foreignexchange.py in __init__(self, *args, **kwargs)
#      10         Inherit AlphaVantage base class with its default arguments
#      11         """
# ---> 12         super(ForeignExchange, self).__init__(*args, **kwargs)
#      13         self._append_type = False
#      14         if self.output_format.lower() == 'csv':
#
# /opt/anaconda3/lib/python3.8/site-packages/alpha_vantage/alphavantage.py in __init__(self, key, output_format, treat_info_as_error, indexing_type, proxy, rapidapi)
# ...
